# %% [markdown]
# # Example Figures

# %% [markdown]
# Cite figures in place.

# %%
from IPython.display import Image, display
metadata={
    "jdh":{
        "module": "object",
        "object": {
          "type": "image",
          "source": [
            "Image from page 10 of \"Bolgiano's seeds\" (1920)",
            "Internet archive book images, no known copyright restrictions"
          ]
        }
    }
}
display(Image("https://live.staticflickr.com/347/20364732206_78ddffa464_c_d.jpg"), metadata=metadata)

# %% [markdown]
# In this case, the caption of the [Fig. 1](figure-1) is *being generated* from inside the cell.

# %%
display(Image("https://live.staticflickr.com/5585/14580779517_13e6124f45_c_d.jpg"))

# %% [markdown]
# In [Fig. 2](figure-2) there is no caption. Just remember to use the markdown link with the corresponding tag: `[Fig. 2](figure-2)`

# %% [markdown]
# You can link [figure 1](figure-1) everywhere in the article... corporis suscipit laboriosam, nisi ut aliquid ex ea commodi consequatur? Quis autem vel eum iure reprehenderit qui in ea voluptate velit esse quam nihil molestiae consequatur, vel illum qui dolorem eum fugiat quo voluptas nulla pariatur?"

# %% [markdown]
# In [figure 3](figure-3) below, a different tag is used: `full-width` allows to use the full screen width. In addition to this tag, a different column layout is used and printed together with the image.

# %%
metadata={
    "jdh":{
        "module": "object",
        "object": {
          "type": "image",
          "bootstrapColumLayout": { "md": { "offset":0, "span": 12 } },
          "source": [
            "Image from page 296 of \"Astronomy for the use of schools and academies\" (1882) [see on Flickr](https://www.flickr.com/photos/internetarchivebookimages/14577695748/in/photolist-odbv4S-x62MGd-owapik-w9E5eF-wqnBpe-os19n5-ovBtqL-tjbYMU-tnShHX-owcKRv-w6LTdz-tk19up-REiC82-oeTSeu-oybGCt-trzNuS-2k2SXH8-ie7nPb-odyVLd-qrHYDb-2k2SkeF-otHZfn-oufdNp-tj8n4V-owkBS2-of26FN-sE6AsK-owtGE2-ovY5qo-ocdipG-ouk3Xh-xryuTU-ow5xdH-y7hSr6-ottvGu-cyf2Wf-odMXRR-5tVWDN-ow9GpE-5tVRnS-6Xcp3B-5tRBEx-6XgCqs-ownf5D-odr6tN-owt4fc-ow3BfF-wYnWxj-wP89hf-xjNUyR)",
            "\"Struve, in 1851, advanced the startling theory that the inneredge of the ring was gradually approaching the planet, the ASTRONOMY. ",
            "[...] The theory was based upon the descriptions and drawings of the rings by the astronomers of the seventeenth century, especially Huyghens, and the measures made by later astronomers up to 1851. This supposed change in the dimension of the ring is shown in Fig. 300.\""
          ]
        }
    }
}
display(Image("https://live.staticflickr.com/3850/14577695748_3f49d841fc_k_d.jpg"), metadata=metadata)
