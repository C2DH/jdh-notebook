# %% [markdown]
# # A Narrative Experiment: Scrollitelling

# %% [markdown]
# How to write contents for step by step narrative of a figure? Let's see how in this brief notebook.

# %% [markdown]
# First of all, let's write some content that will appear in the **narrative** layer.

# %% [markdown]
# Narration of something

# %% [markdown]
# This will appear in the hermeneutic layer, as simple "hermeneutic" paragraph.
#
# It is composed by many lines, only the first line is visible in the narrative layer...

# %% [markdown]
# Then, let's write again some other content to appear in the same hermeneutic layer.

# %%
from IPython.display import Image, display
metadata={
    "jdh":{
        "module": "object",
        "object": {
          "type": "image",
          "source": [
            "Image from page 10 of \"Bolgiano's seeds\" (1920)",
            "Internet archive book images, no known copyright restrictions"
          ]
        }
    }
}
display(Image("https://live.staticflickr.com/5573/14781178161_f449e71c68_c_d.jpg"), metadata=metadata)

# %% [markdown]
# And finally, our conclusion

# %% [markdown]
# (two paragraphs)
