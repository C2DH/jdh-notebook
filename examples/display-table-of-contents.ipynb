# %% [markdown]
# # Table of Contents

# %% [markdown]
# This example displays a really complex table of contents for an almost empty article.
# A table of contents is automatically generated from the markdown contents (using the various headings) and takes into account *figures*, *tables* and all headings in the hermeneutic layers.

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Section 1

# %% [markdown]
# ### Section 2

# %%
import base64
from IPython.display import Image, display
metadata={
    "jdh":{
        "module": "object",
        "object": {
          "type": "image",
          "source": [
            "Image from page 10 of \"Bolgiano's seeds\" (1920)",
            "Internet archive book images, no known copyright restrictions"
          ]
        }
    }
}
figure = Image("https://live.staticflickr.com/347/20364732206_78ddffa464_c_d.jpg", width=150)
display(figure, metadata=metadata)

# %% [markdown]
# ## hermeneutic content

# %% [markdown]
# ### Section h.1

# %% [markdown]
# ## Analysis

# %% [markdown]
# Editor|1641|1798|1916
# ---|---|---|---
# Senan|0.55|0.4|0.3
# Henry|0.71|0.5|0.63

# %% [markdown]
# ## Conclusions

# %% [markdown]
# ### Conclusion section
