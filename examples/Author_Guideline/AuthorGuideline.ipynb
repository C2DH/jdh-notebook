# %% [markdown]
# # Guidelines for authors

# %% [markdown]
# The journal makes use of **ipynb notebooks** to publish the articles. In addition to that, there is a couple of rules to *format content* and *visualize datasets*. The article shall be written in English (and thus use English style typography).

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Process of creating an article in the Journal of Digital History"
            ]
        }
    }
}
display(Image("media/JDH_process_1.png"), metadata=metadata)

# %% [markdown]
# ## Step 1: Setup the writing environment (Windows)

# %% [markdown]
# ### Install Jupyter Notebook via Docker (Windows)

# %% [markdown]
# For writing articles, we use [Jupyter Notebook](https://jupyter.org/) as it's the best tool to create and share documents that contain live code, media and text.

# %% [markdown]
# To install Jupyter Notebook on your device, we use [Docker](https://www.docker.com/). This tool helps us to set up the JDH writing environment wrapped in a lightweight execution environment called _containers_.

# %% [markdown]
# Download and install [Docker Desktop](https://www.docker.com/products/docker-desktop/) for Windows.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Website: Docker Desktop installation"
            ]
        }
    }
}
display(Image("media/Docker_Desktop3.png"), metadata=metadata)

# %% [markdown]
# Make sure to check mark the use of WSL 2 (Windows Subsystem for Linux). It enables users to work in a Linux-based development environment and build Linux-based containers.

# %% [markdown]
# Making use of Linux in this context is beneficial, as it requires fewer resources  in terms of CPU, memory, and storage than solely using Windows or a virtual machine (VM) for example.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: WSL 2"
            ]
        }
    }
}
display(Image("media/install_docker_desktop_1.png"), metadata=metadata)

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: installation"
            ]
        }
    }
}
display(Image("media/install_docker_desktop_2.png"), metadata=metadata)

# %% [markdown]
# It is possible that the WSL installation is incomplete. In this case follow the [link](https://aka.ms/wsl2kernel) as requested.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: incomplete WSL 2 installation"
            ]
        }
    }
}
display(Image("media/WSL_installation_incomplete.png"), metadata=metadata)

# %% [markdown]
# Once you’ve installed Docker, run the application. (Read and) accept their service agreement.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: Service Agreement"
            ]
        }
    }
}
display(Image("media/Docker_Service_Agreement.png"), metadata=metadata)

# %% [markdown]
# Sign in or sign up for a user account.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: start screen and sign in"
            ]
        }
    }
}
display(Image("media/Signin_Docker_Desktop.png"), metadata=metadata)

# %% [markdown]
# You will be forwarded to their website to set up your Docker account.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker website: account creation"
            ]
        }
    }
}
display(Image("media/Docker_Signup_Account.png"), metadata=metadata)

# %% [markdown]
# ### Use the terminal to test the getting-started guide

# %% [markdown]
# Once you’re logged in, you can try (or skip) the mentioned tutorial and run a container by copy pasting the command into the _terminal_.

# %% [markdown]
# In Windows, the terminal or console typically used is the PowerShell.
# A terminal is simply a text-based interface to the computer. There you can type commands, manipulate files, execute programs, and open documents. (When working in a terminal, the current directory is called your working directory.)

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: Containers"
            ]
        }
    }
}
display(Image("media/Docker_Container_Command.png"), metadata=metadata)

# %% [markdown]
# To run the terminal, search for it in the Windows search bar (press the Windows key and start typing _Powershell_), right click on it to select _run as administrator_ to ensure you have all rights necessary to perform all following operations.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Windows Start Menu: PowerShell"
            ]
        }
    }
}
display(Image("media/Windows_Start_Terminal.png"), metadata=metadata)

# %% [markdown]
# You can select where you want to place the content by using _cd_ followed by the destination folder.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "PowerShell: cd command"
            ]
        }
    }
}
display(Image("media/Terminal_cd_command.png"), metadata=metadata)

# %% [markdown]
# Then run the suggested command:
#
# `docker run -d -p 80:80 docker/getting-started`
#
# Docker will check if the image is already locally on your machine and if not will pull it.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "PowerShell: getting-started"
            ]
        }
    }
}
display(Image("media/terminal_getting_started_container.png"), metadata=metadata)

# %% [markdown]
# Open Docker for Desktop and you will see the _getting-started_ image in the left-handed Container tab. It is already running. In order to view the content, click on the _open with browser_ button.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: Open with browser button"
            ]
        }
    }
}
display(Image("media/Container_openbrowser.png"), metadata=metadata)

# %% [markdown]
# In the getting started guide, you will get an explanation for the command you just ran. Afterwards, close the tab again and stop the container.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: getting started guide"
            ]
        }
    }
}
display(Image("media/getting-started_docker_website.png"), metadata=metadata)

# %% [markdown]
# ## Step 2: Setup the Github repository

# %% [markdown]
# As a next step you need to connect a repository, a place where all your data is stored in one place.

# %% [markdown]
# A repository (or repo) is a storage location for software packages. We use the code hosting platform Github which enables version control and collaboration.

# %% [markdown]
# ### Install Github Desktop and sign up for an account

# %% [markdown]
# Download and install [Github Desktop for Windows](https://desktop.github.com/).

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Github website: download Github Desktop for Windows"
            ]
        }
    }
}
display(Image("media/Github_Desktop.png"), metadata=metadata)

# %% [markdown]
# Once installed, sign up for an account.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Github Desktop: Sign in or create an account"
            ]
        }
    }
}
display(Image("media/Welcome_GitHub_Desktop.png"), metadata=metadata)

# %% [markdown]
# ### Clone the jdh-jupyter stack and connect it with Docker

# %% [markdown]
# In order to clone the jdh repository to have a local copy on your machine, select _File > Clone repository_ (or use Ctrl + Shift + O).

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Github Desktop: File > Clone repository"
            ]
        }
    }
}
display(Image("media/Github_Clone_repo.png"), metadata=metadata)

# %% [markdown]
# Search for the _journal-of-digital-history-jupyter-stack_ in the search bar and select a local path where you want the repository to be saved. Select the Clone button to proceed.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Github Desktop: clone repository jdh-jupyter-stack"
            ]
        }
    }
}
display(Image("media/Github_Clone_repo_highlighted.png"), metadata=metadata)

# %% [markdown]
# The repository will be cloned.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Github Desktop: progress bar cloning repo"
            ]
        }
    }
}
display(Image("media/Cloning_jdh-jupyter-stack.png"), metadata=metadata)

# %% [markdown]
# Next, we will connect the repository with Docker. In Github Desktop, select _Show in Explorer_.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Github Desktop: Show in Explorer"
            ]
        }
    }
}
display(Image("media/Show_repo_in_Explorer.png"), metadata=metadata)

# %% [markdown]
# Copy the path in Explorer.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Explorer: copy path"
            ]
        }
    }
}
display(Image("media/Copy_path_in_explorer2.png"), metadata=metadata)

# %% [markdown]
# Go to the terminal and use the _cd_ command to move to the repo folder.
#
# Then, use the command:
#
# `docker-compose up`

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "PowerShell: command cd and docker-compose up"
            ]
        }
    }
}
display(Image("media/terminal_docker_up3.png"), metadata=metadata)

# %% [markdown]
# In Docker you can see the new image.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: Images"
            ]
        }
    }
}
display(Image("media/Docker_Images.png"), metadata=metadata)

# %% [markdown]
# ### Use the JDH template notebook

# %% [markdown]
# In the next step, the JDH template repository needs to be connected. To do this, select _File > Clone a repository_ again. Search for _tempate_repo_JDH_ if you will use the programming language Python (select this option if this is your first time).

# %% [markdown]
# If you will use the programming language R, search for _template_repo_JDH_R_ and [activate the R kernel](https://irkernel.github.io/installation/).

# %% [markdown]
# Make sure the local path is in the subfolder _work_.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Github Desktop: Clone template_repo_JDH"
            ]
        }
    }
}
display(Image("media/copy_template_repo.png"), metadata=metadata)

# %% [markdown]
# Go back to your terminal and make sure you’re in the right folder. Otherwise locate the path in Github via _Repository > Show in Explorer_ (or Ctrl + Shift + F) and copy the path. In the terminal, use the command _cd_ and paste the path.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Github Desktop: Repository > Show in Explorer"
            ]
        }
    }
}
display(Image("media/show_in_Explorer_option2.png"), metadata=metadata)

# %% [markdown]
# Use the command:
#
# `docker-compose up`

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Powershell: command docker-compose up"
            ]
        }
    }
}
display(Image("media/Terminal_run_compose_up_command.png"), metadata=metadata)

# %% [markdown]
# Back in Docker you can open the new container in Jupyter Notebook by selecting _open with browser_.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: open with browser"
            ]
        }
    }
}
display(Image("media/template_repo_open_in_browser.png"), metadata=metadata)

# %% [markdown]
# Jupyter Notebook will open and you need to enter a token.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Jupyter Notebook: token authentication"
            ]
        }
    }
}
display(Image("media/Jupyter_Notebook_Token.png"), metadata=metadata)

# %% [markdown]
# You will find the token in the terminal. Select and copy it (Ctrl + C).

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Powershell: copy the token"
            ]
        }
    }
}
display(Image("media/Terminal_Token.png"), metadata=metadata)

# %% [markdown]
# Paste the code (Ctrl + P) and log in.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Jupyter Notebook: paste the token"
            ]
        }
    }
}
display(Image("media/Paste_token_JN.png"), metadata=metadata)

# %% [markdown]
# You will see the JDH template repository folder.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Jupyter Notebook: folder template repo JDH"
            ]
        }
    }
}
display(Image("media/notebook_list_template.png"), metadata=metadata)

# %% [markdown]
# Select the tab _Nbextensions_.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Jupyter Notebook: nbextensions tab"
            ]
        }
    }
}
display(Image("media/enable_Nbextensions.png"), metadata=metadata)

# %% [markdown]
# Disable the checkmark at the top to _enable_ the configuration details. Make sure _cite2c_ is checked.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Jupyter Notebook: cite2c plugin"
            ]
        }
    }
}
display(Image("media/enable_cite2c.png"), metadata=metadata)

# %% [markdown]
# Go back to the _Files_ tab, navigate into the folder and open the .ipynb file.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Jupyter Notebook: template notebook"
            ]
        }
    }
}
display(Image("media/template_notebook_in_list.png"), metadata=metadata)

# %% [markdown]
# A new tab will open to run the template notebook.

# %% [markdown]
# ### Setup the bibliography via the cite2c plugin (Zotero)

# %% [markdown]
# For citation management, we use the cite2c plugin. It connects your Zotero library to the notebook and inserts the citations into the markdown cells. The citations are stored in the notebook metadata and references by an ID. It also renders a bibliography and inline citations.
#
# Zotero is an open-source reference management software to manage bibliographic data and related research material.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Jupyter Notebook: run template notebook"
            ]
        }
    }
}
display(Image("media/notebook_template.png"), metadata=metadata)

# %% [markdown]
# Click on the plus button to _insert a new cell_.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Jupyter Notebook: insert a new cell"
            ]
        }
    }
}
display(Image("media/insert_new_cell.png"), metadata=metadata)

# %% [markdown]
# Next, click on insert a citation.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Jupyter Notebook: insert a citation"
            ]
        }
    }
}
display(Image("media/insert_citation_jupyter.png"), metadata=metadata)

# %% [markdown]
# A new browser tab will open with Zotero. Login or register for an account.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Zotero website: Log in or register account"
            ]
        }
    }
}
display(Image("media/login_signup_Zotero.png"), metadata=metadata)

# %% [markdown]
# You will be asked to connect your account by using a key. Click _accept defaults_.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Zotero: Connect with cite2c plugin"
            ]
        }
    }
}
display(Image("media/Zotero_key_description.png"), metadata=metadata)

# %% [markdown]
# The tab will close and you will return to your notebook. Click OK.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Jupyter Notebook: Zotero User ID"
            ]
        }
    }
}
display(Image("media/Zotero_user_ID_OK.png"), metadata=metadata)

# %% [markdown]
# You can now insert a citation as a test.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Jupyter Notebook: insert example citation"
            ]
        }
    }
}
display(Image("media/sample_citation.png"), metadata=metadata)

# %% [markdown]
# Change the cell type to _Markdown_. For a detailed guide on how to use citations, please refer to Chapter x.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Jupyter Notebook: cell type Markdown"
            ]
        }
    }
}
display(Image("media/jupyter_change_cell_to_markdown.png"), metadata=metadata)

# %% [markdown]
# Make sure you are part of the [JournalofDigitalHistory](https://www.zotero.org/journalofdigitalhistory) group in Zotero (if not request to join).

# %% [markdown]
# You can save your notebook and close and halt it. This will close the notebook tab as well. You will return to your list of notebooks.

# %% [markdown]
# ### Stop or continue working on your notebook

# %% [markdown]
# You can _save_ your notebook and then _close and halt_ it. This will close the notebook tab as well. You will return to your list of notebooks.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Jupyter Notebook: close and halt notebook"
            ]
        }
    }
}
display(Image("media/JN_Close_and_Halt.png"), metadata=metadata)

# %% [markdown]
# In Docker Desktop click the _Stop_ button.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: stop container"
            ]
        }
    }
}
display(Image("media/Stop_docker_container.png"), metadata=metadata)

# %% [markdown]
# To run your notebook again (next time), start Docker and press _Start_.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: start container"
            ]
        }
    }
}
display(Image("media/Start_container.png"), metadata=metadata)

# %% [markdown]
# You might be asked to enter a token again. If you don’t have a terminal running in the background, you can find it by selecting the whole line of the container in Docker Desktop.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: navigate to container logs"
            ]
        }
    }
}
display(Image("media/click_logs_docker.png"), metadata=metadata)

# %% [markdown]
# This will get you to the Logs. There you can copy the token.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: container logs"
            ]
        }
    }
}
display(Image("media/Docker_Logs.png"), metadata=metadata)

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: token in the logs"
            ]
        }
    }
}
display(Image("media/Token_in_Logs.png"), metadata=metadata)

# %% [markdown]
# Press the return button to get back to the list of Containers.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Docker Desktop: back navigation"
            ]
        }
    }
}
display(Image("media/back_navigation.png"), metadata=metadata)

# %% [markdown]
# If you already have a repository and you want to link it with Docker, follow the same procedure as before, by cloning your repo into the subfolder _work_.

# %% [markdown]
# As soon as you start Docker and select _open in browser_, you will be able to see all your connected repositories in the notebook list.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Jupyter Notebook: list of all repositories"
            ]
        }
    }
}
display(Image("media/multiple_repos_notebook_list.png"), metadata=metadata)

# %% [markdown]
# ## Step 1: Setup the writing environment (Mac)

# %% [markdown]
# ### Install Jupyter Notebook via Docker (Mac)

# %% [markdown]
# ### Alternate writing environment

# %% [markdown]
# If you already work with Anaconda, you can also use that to produce your articles. Refer to [this page for anaconda's installation](https://docs.anaconda.com/anaconda/install/) and to [this one](https://docs.anaconda.com/anaconda/navigator/) to use anaconda navigator to launch jupyter notebooks.

# %% [markdown]
# In case you use Anaconda, make sure you have the following versions for best compatibility:
#
# nbconvert: 6.0.7
#
# jupyter client: 6.1.7
#
# jupyter-notebook: 6.2.0

# %% [markdown]
# ## Step 3: Write, Design & Preview

# %% [markdown]
# ### Markdown

# %% [markdown]
# Markdown is a simple and easy-to-use markup language you can use to format virtually any document.

# %% [markdown]
# If you are new to Markdown, refer to [this](https://www.markdownguide.org/getting-started/) guide for how it works and what you can do with it, [here](https://www.markdownguide.org/basic-syntax/) you'll find the basic syntax and [here](https://www.markdownguide.org/extended-syntax/) the extended syntax.

# %% [markdown]
# ### Citation

# %% [markdown]
# Here's an example of an citation in a cell in Markdown versus an executed cell:

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "cite2c: inline citation in Markdown"
            ]
        }
    }
}
display(Image("media/screenshot_inline_citation_markdown.png"), metadata=metadata)

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "cite2c: inline citation in executed cell"
            ]
        }
    }
}
display(Image("media/screenshot_inline_citation.png"), metadata=metadata)

# %% [markdown]
# When citing, put the citation in brackets, so it will be rendered like this in the article:

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Markdown for citation, executed cell and generated article"
            ]
        }
    }
}
display(Image("media/citation.png"), metadata=metadata)

# %% [markdown]
# For multiple citations, seperate the authors by a comma:

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Markdown for multiple citations, executed cell and generated article"
            ]
        }
    }
}
display(Image("media/citation_multiple.png"), metadata=metadata)

# %% [markdown]
# The last cell in your notebook is reserved for inserting the bibliography. Click the _Insert bibliography_ button in the toolbar and execute (Ctrl + Enter) the cell to see the result.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "cite2c: insert bibliography in Markdown"
            ]
        }
    }
}
display(Image("media/screenshot_bibliography.png"), metadata=metadata)

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "cite2c: view rendered bibliography"
            ]
        }
    }
}
display(Image("media/screenshot_bibliography_rendered.png"), metadata=metadata)

# %% [markdown]
# ### Cell tagging

# %% [markdown]
# In order to render the notebook on the frontend, we are working with tags to mark cells with special content like figures, tables or the  hermeneutics layer.
# Narrative cells are generally not tagged, with one exception that is explained in chapter x.

# %% [markdown]
# Here's an overview of the most important tags:

# %% [markdown]
# Function | Tag | Markdown | Explanation
# --- | --- | --- | ---
# Title | `title` | h1 (#) | This tag is used for the title of the article.
# Contributor | `contributor` | h3 (###) | One contributor per cell. Below the name, indicate the role and the affiliation.
# Collaborator | `collaborator` |  | Collaborators can be mentioned like this: First Name, Name / orcid ID / institution.
# Cover Image | `cover` | | Figures are counted automatically and will appear in the table of figures. (Captions will be added via a button?)
# Disclaimer | `disclaimer` | | This disclaimer can be used for certain announcements. It will be color-coded in orange.
# Keywords | `keywords` | | Keywords are to be separated by comma (“,”)
# Abstract | `abstract` | | This cell features the abstract of an article with a max./min length of x characters.
# Chapter Title | | h2 (##) | Chapter titles are always written in h2.
# Table | `table(-insert-name)-*` | | Tables need to be tagged using `table-` and then adding a unique name, ending with `-*`
# Figure | `figure(-insert-name)-*` | | Figures need to be tagged using `figure-` and then adding a unique name, ending with `-*` Captions can be added, see chapter x
# Gallery of Figures | `gallery(-insert-name)-*` | | Multiple figures (one per cell) can be (each) tagged with `gallery-(insert-name)-*` to combine them into a gallery. For more details see chapter x
# Hermeneutics | `hermeneutics` |  | Methodology is always placed on the hermeneutics layer.
# Hermeneutics Step | `hermeneutics-step` |  | This scrollytelling method is explained in chapter x
# Narrative Step | `narrative-step` |  | This scrollytelling method is explained in chapter x
# Hermeneutics, Narrative | `narrative` `hermeneutics` |  | Tagging both layers is a special use case explained in chapter x

# %% [markdown]
# For the header section we use the tags `title`, `contributor`, `cover`, `disclaimer` (if needed), `keywords` and `abstract` to show the article in a certain structure.

# %% [markdown]
# In the [JDH template notebook](https://github.com/C2DH/template_repo_JDH/blob/main/author_guideline_template.ipynb) you will already find two type of licenses: Creative Commons Attribution License [CC-BY](https://creativecommons.org/licenses/by/4.0/)  or [CC-BY-NC-ND](https://creativecommons.org/licenses/by-nc-nd/4.0/). Please select the one that suits your work.

# %% [markdown]
# After the header section
# - The first title is always `introduction`.
# - The first cell after that should be a `narrative` cell in Markdown.

# %% [markdown]
# In order to tag cells, enable the tagging function via _View > Cell Toolbar > Tags_.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Enable cell tagging in the toolbar"
            ]
        }
    }
}
display(Image("media/gif_view_tags.gif"), metadata=metadata)

# %% [markdown]
# ### Hermeneutics

# %% [markdown]
# The articles in our journal have a unique layer approach which is also reflected in the way the notebooks are written.

# %% [markdown]
# Use Case | Function | Tag | Markdown | Explanation
# --- | --- | --- | --- | ---
# 1 | Hermeneutics | `hermeneutics` | | Everything related to hermeneutics should be tagged accordingly.
# 2 | Input on the hermeneutics layer, output on the narrative layer | `hermeneutics` `narrative` | | Sometimes it makes sense to have code input on the hermeneutics layer, but the output should be visible on the narrative layer as part of the story the author wants to tell. Tag both for these cases.
# 3 | Hermeneutics Step | `hermeneutics-step` | | Break long passages into a step by step manner to facilitate understanding while showing something visual. See chapter 4.3

# %% [markdown]
# ### Use cases

# %% [markdown]
# #### Use case 1: Hermeneutics

# %% [markdown]
# Everything that refers to the methodology will be placed on the hermeneutics layer. The cells should be tagged with `hermeneutics`.
# On the frontend, these cells will appear in a collapsed accordion that can be expanded when needed.

# %% [markdown]
# Every hermeneutic cell should have a headline to begin with in order to show it properly in the generated article:

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "figure 17: hermeneutics without a title"
            ]
        }
    }
}
display(Image("media/empty_h-layer.png"), metadata=metadata)

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "figure 17: hermeneutics with a title"
            ]
        }
    }
}
display(Image("media/filled_h-layer.png"), metadata=metadata)

# %% [markdown]
# #### Use case 2: input H-layer, output N-layer

# %% [markdown]
# Sometimes it makes sense to have code input on the hermeneutics layer, but the output should be visible on the narrative layer as part of the story the author wants to tell. For this special case, we recommend tagging `hermeneutics` and `narrative`.

# %% [markdown]
# ### Narrative and hermeneutics steps

# %% [markdown]
# Using visuals can often support how a certain methodology is setup. For this purpose, there's a special method we can use by tagging `hermeneutics-step` for the hermeneutics layer or `narrative-step` when on the narrative layer.
# Here's an example of how this could look like:

# %%
from IPython.display import VimeoVideo

metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "figure 18: fingerprint explanation"
            ]
        }
    }
}

# Vimeo
display(VimeoVideo('581212277?h=b04725f547','100%','347'), 
        metadata=metadata)
# Out:
#         <iframe
#             width="100%"
#             height="347"
#             src="https://player.vimeo.com/video/581212277?h=b04725f547"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Captions for figures & tables

# %% [markdown]
# Figures and tables are a bit special. Depending on the type of cell there are the following use cases and guides on writing a caption:

# %% [markdown]
# Use Case | Cell Type | Content Type | Tag | Caption
# --- | --- | --- | --- | ----
# 1 | Code | figure | `figure-1` | The caption is directly added in the metadata of the code cell.
# 2 | Code | figure-1, figure-2 | `figure-1` | The caption is directly added in the metadata of the code cell for each figure. The cell caption is written via the cell metadata.
# 3 | Code | Table | `table-1` | The caption is directly added in the metadata of the code cell.
# 4 | Markdown | Table | `table-1` | The caption is written via the cell metadata.

# %% [markdown]
# ### Use Cases

# %% [markdown]
# #### Use case 1: figure in code cell

# %% [markdown]
# Figures like images for example are tagged with "figure-(number)". Figures need to be **MANUALLY** incremented.
# In order to add a caption (title and copyright), we use **metadata** which will be visible on the narrative layer:
# ```
#     "tags": [figure-1],
#     "jdh": {
#             "object": {
#             "source": [
#                 "Image from page 10 of \Book Title\ (1920)",
#                 "Internet archive book images, no known copyright restrictions"
#             ]
#         }
#     }
# }
# ```

# %% [markdown]
# To include **videos**, use the tag "figure-(number)" as well. Here's an example for Vimeo:
#
# ```
# from IPython.display import VimeoVideo
#
# metadata={
#     "jdh": {
#         "module": "object",
#         "object": {
#             "type":"image",
#             "source": [
#                 "figure (number): caption"
#             ]
#         }
#     }
# }
#
# # Vimeo
# display(VimeoVideo('ID','100%','height'),
#         metadata=metadata)
# ```

# %% [markdown]
# #### Use case 2: gallery

# %% [markdown]
# We follow a cell-centric approach, meaning **one** cell should only contain **one** figure (and thus only **one** caption). However, we offer a gallery view to showcase multiple pictures in an appealing way. Use the tag *gallery-(number)* for all cells that contain one figure each to combine them into a gallery on the generated preview of the article.

# %% [markdown]
# (Picture to be added as soon as implemented)

# %% [markdown]
#    * tag the cell with `figure-1`
#    * modify the cell metadata to add the caption for the whole cell

# %% [markdown]
# #### Use case 3: table in code cell

# %% [markdown]
# Use case 3 uses the same principles as use case 1 and 2. Just replace `figure` with `table`.

# %% [markdown]
# #### Use case 4: table in markdown cell

# %% [markdown]
# For writing a caption for a table in a markdown cell, add the caption via the cell metadata.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "figure 17: write one cell caption for the table(s)"
            ]
        }
    }
}
display(Image("media/screenshot_cell_metadata_table.png"), metadata=metadata)

# %% [markdown]
# ### Links

# %% [markdown]
# Any links that are included should open in a **new tab**, so the user can keep reading from the position he or she is at that given moment. It can be achieved in the following way:
#
# `[link](URL){:target="_blank"}`

# %% [markdown]
# ### Submitting

# %% [markdown]
# - For the peer review, we need two versions of the notebook, anonymized and a non anonymized version.
# - Submit **both version** via a private or public repo on Github
# - Send an email to mailto:jdh.admin@uni.lu when done.

# %% [markdown]
# ### Optional features: table of contents & collapsible headings

# %% [markdown]
# To keep a better overview of your notebook, we suggest you use these three additional features.

# %% [markdown]
# 1. In nbextension, select the **table of contents** feature to activate it. Open a notebook. In the toolbar select the table of contents button to show it as a sidebar next to the notebook.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "figure 11: table of contents"
            ]
        }
    }
}
display(Image("media/screenshot_ToC.png"), metadata=metadata)

# %% [markdown]
# 2. In nbextension, select the **collapsible headings** feature to activate it. Open a notebook. You will see the triangle next to each cell. You can easily expand or contract it. This way you can hide certain section to keep a better overview of your progress.

# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "figure 12: collapsible headings"
            ]
        }
    }
}
display(Image("media/screenshot_collapsible_headings_example.png"), metadata=metadata)

# %% [markdown]
# ### Github account

# %% [markdown]
# While working in the notebooks, every author needs to create a Github repository (per article). You can create your own repository [here](https://github.com/). You can request a free academic account.
#
# In order to review the author’s notebooks, the authors need to provide access rights in Github to the user [jdh-observer](https://github.com/jdh-observer).

# %% [markdown]
# ### Folder structure

# %% [markdown]
# When delivering the notebook, we require the following files in this precise folder structure:

# %% [markdown]
# File |Type | Explanation
# --- | --- | ---
# readme | .md file | This file contains the abstract of the article and the keywords.
# requirements | .txt file | This file contains all the versions of the required libraries to function properly.
# notebook | .ipynb file | This file is placed in the root folder and contains the full title of the article, separating the words with "-" inbetween
# media | folder | This folder contains all media like images, videos, etc.
# script | folder | This folder contains all the code and data needed for the notebook like the CSV-files.

# %% [markdown]
# [Here](https://github.com/C2DH/template_repo_JDH) is an example for the folder structure in a repository:

# %%
from IPython.display import Image
from IPython.core.display import HTML 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "figure 13: repository folder structure"
            ]
        }
    }
}
display(Image("media/screenshot_github.png"), metadata=metadata)

# %% [markdown]
# Every article will have a **launch binder** button implemented for a quick (read-only) view of the notebook.

# %% [markdown]
# For the filename naming, please adhere to the following guidelines:
# - no space in the name
# - no point but for the extension
# - no upper case (only lower case)
# - if a date is at the beginning of the name: YYYYMMDD
# - english quotemarks

# %% [markdown]
# After committing changes to the notebook in Github, the result can be viewed in the Notebook Viewer:

# %%
from IPython.display import Image
from IPython.core.display import HTML 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "figure 14: notebook viewer"
            ]
        }
    }
}
display(Image("media/Jupyter_notebook_viewer.png"), metadata=metadata)

# %% [markdown]
# ## Fingerprint

# %% [markdown]
# In line with our data-driven approach in this journal, we wanted this concept to be reflected visually in the cover for each article as well. We therefore created a data visualization that reflects the unique characteristics of the author's writing style, a sort of <em>fingerprint</em> that readers can use to identify the nature of the article.

# %%
from IPython.display import VimeoVideo

metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "figure 18: fingerprint explanation"
            ]
        }
    }
}

# Vimeo
display(VimeoVideo('618021919?h=b04725f547','100%','347'), 
        metadata=metadata)
# Out:
#         <iframe
#             width="100%"
#             height="347"
#             src="https://player.vimeo.com/video/618021919?h=b04725f547"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
