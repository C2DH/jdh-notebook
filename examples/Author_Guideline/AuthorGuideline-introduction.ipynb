# %%
from IPython.display import Image 
metadata={
    "jdh": {
        "module": "object",
        "object": {
            "type":"image",
            "source": [
                "Process of creating an article in the Journal of Digital History"
            ]
        }
    }
}
display(Image("media/JDH_process_1_1.png"), metadata=metadata)

# %% [markdown]
# Here's an overview of the submission workflow:
# 1. Setup the writing environment by installing Docker.
# 2. Setup the Github repository, make use of the JDH template notebook and connect the citation plugin in Jupyter.
# 3. Guidelines around writing, design and how to preview the notebook.
# 4. Make the article reproducable, go through peer, technical and design review.
# 5. Publish the article.
